# %%
import pandas as pd
df1=pd.read_csv('whole_enh_num_20_r_5.0_g_1.0_s1_0.950_s2_1.010_ma_5.5_mr_5.5_AC_100.txt',sep=' ')
df2=pd.read_csv('middle_enh_num_20_r_5.0_g_1.0_s1_0.950_s2_1.010_ma_5.5_mr_5.5_AC_100.txt',sep='\s+')
df3=pd.read_csv('upper_enh_num_20_r_5.0_g_1.0_s1_0.950_s2_1.010_ma_5.5_mr_5.5_AC_100.txt',sep='\s+')
df4=pd.read_csv('lower_enh_num_20_r_5.0_g_1.0_s1_0.950_s2_1.010_ma_5.5_mr_5.5_AC_100.txt',sep='\s+')
df1
# Out:
#     cl      prob
# 0    0  0.000000
# 1    1  0.051920
# 2    2  0.089936
# 3    3  0.082655
# 4    4  0.072193
# 5    5  0.059834
# 6    6  0.046762
# 7    7  0.034606
# 8    8  0.024440
# 9    9  0.016497
# 10  10  0.010636
# 11  11  0.006739
# 12  12  0.004259
# 13  13  0.002885
# 14  14  0.002201
# 15  15  0.001966
# 16  16  0.002188
# 17  17  0.004164
# 18  18  0.020021
# 19  19  0.155323
# 20  20  0.310777
# 21  21  0.000000
# 22  22  0.000000

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(figsize=(5,5))
plt.plot(df1.cl,df1.prob,'b-o',label='AER')
plt.plot(df2.cl,df2.prob,'r-o',label='E')
plt.plot(df3.cl,df3.prob,'y-o',label='AE')
plt.plot(df4.cl,df4.prob,'m-o',label='RE')
plt.legend()
plt.xlabel('cluster size')
plt.ylabel('probability')
plt.title('enh=20,r=5,g=1')
plt.show()

# %%
import matplotlib.pyplot as plt
x1=[1,5,10,20,30,40,50]
y1=[0.331,0.24,0.21,0.196,0.19,0.19,0.19]
y2=[0.313,0.401,0.408,0.413,0.42,0.435,0.452]
y3=[0.335,0.493,0.593,0.605,0.606,0.607,0.608]
y4=[0.254,0.087,0.048,0.029,0.025,0.025,0.025]
# y5=[0.335,0.493,0.593,0.608,0.612,0.619,0.619]
# y6=[0.333,0.159,0.101,0.089,0.131,0.155,0.155]
fig,ax=plt.subplots(figsize=(5,4))
plt.plot(x1,y1,'b-o',label='E')
plt.plot(x1,y2,'r-o',label='A+E+R')
plt.plot(x1,y3,'y-o',label='R+E')
plt.plot(x1,y4,'k-o',label='A+E')
# plt.plot(x1,y5,'m-o',label='RE_OFF')
# plt.plot(x1,y6,'g-o',label='RE_ON')
plt.legend()
plt.xlabel('Enhancer number')
plt.ylabel('Randomness parameter')
# plt.title('enh=20,r=5,g=1')
plt.savefig('ARE_noise.png')
plt.show()

# %%
import matplotlib.pyplot as plt
x1=[1,5,10,20,30,40,50]
y1=[0.333,0.16,0.099,0.089,0.13,0.15,0.15]
y2=[0.255,0.086,0.048,0.028,0.024,0.027,0.041]
y3=[0.328,0.463,0.567,0.599,0.601,0.601,0.601]
y4=[0.256,0.111,0.082,0.063,0.058,0.057,0.057]
y5=[0.335,0.493,0.593,0.608,0.612,0.619,0.619]
y6=[0.333,0.159,0.101,0.089,0.131,0.155,0.155]
fig,ax=plt.subplots(figsize=(5,4))
plt.plot(x1,y1,'b-o',label='AE_OFF')
plt.plot(x1,y2,'r-o',label='AE_ON')
# plt.plot(x1,y3,'y-o',label='AER_OFF')
# plt.plot(x1,y4,'k-o',label='AER_ON')
# plt.plot(x1,y5,'m-o',label='RE_OFF')
# plt.plot(x1,y6,'g-o',label='RE_ON')
plt.legend()
plt.xlabel('cluster size')
plt.ylabel('Randomness parameter')
# plt.title('enh=20,r=5,g=1')
plt.savefig('AE_noise.png')
plt.show()

# %%
import matplotlib.pyplot as plt
x1=[1,5,10,20,30,40,50]
y1=[0.333,0.16,0.099,0.089,0.13,0.15,0.15]
y2=[0.255,0.086,0.048,0.028,0.024,0.027,0.041]
y3=[0.328,0.463,0.567,0.599,0.601,0.601,0.601]
y4=[0.256,0.111,0.082,0.063,0.058,0.057,0.057]
y5=[0.335,0.493,0.593,0.608,0.612,0.619,0.619]
y6=[0.333,0.159,0.101,0.089,0.131,0.155,0.155]
fig,ax=plt.subplots(figsize=(5,4))
# plt.plot(x1,y1,'b-o',label='AE_OFF')
# plt.plot(x1,y2,'r-o',label='AE_ON')
# plt.plot(x1,y3,'y-o',label='AER_OFF')
# plt.plot(x1,y4,'k-o',label='AER_ON')
plt.plot(x1,y5,'m-o',label='RE_ON')
plt.plot(x1,y6,'g-o',label='RE_OFF')
plt.legend()
plt.xlabel('Enhancer number')
plt.ylabel('Randomness parameter')
# plt.title('enh=20,r=5,g=1')
plt.savefig('RE_1_noise.png')
plt.show()

# %%
import pandas as pd
df=pd.read_csv('enh_strength_with_ge.txt',sep='\s+')
df
# Out:
#            r/g  avg_cl_E  avg_cl_RE  avg_cl_AE  avg_cl_AER
# 0     0.010000      1.50       1.26       1.28        1.02
# 1     0.014286      1.51       1.26       1.30        1.03
# 2     0.020000      1.52       1.27       1.32        1.04
# 3     0.033333      1.53       1.28       1.37        1.07
# 4     0.100000      1.59       1.33       1.76        1.23
# 5     0.100000      1.59       1.33       1.75        1.23
# 6     0.142857      1.64       1.37       2.14        1.34
# 7     0.200000      1.71       1.41       2.94        1.51
# 8     0.300000      1.84       1.51       5.10        1.83
# 9     0.333333      1.89       1.54       5.88        1.95
# 10    0.428571      2.06       1.64       7.74        2.29
# 11    0.500000      2.20       1.73       8.72        2.56
# 12    0.600000      2.44       1.86       9.59        2.93
# 13    0.700000      2.72       2.03      10.15        3.31
# 14    0.714286      2.76       2.05      10.22        3.36
# ...

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(figsize=(5,4))
plt.plot(df['r/g'],df.avg_cl_E,'b-o',label='E')
plt.plot(df['r/g'],df.avg_cl_RE,'r-o',label='RE')
plt.plot(df['r/g'],df.avg_cl_AE,'y-o',label='AE')
plt.plot(df['r/g'],df.avg_cl_AER,'g-o',label='AER')
plt.legend()
plt.xlabel('EP Binding strength')
plt.ylabel('Gene expression')
plt.title('EP Binding strength vs gene expression')
plt.show()
